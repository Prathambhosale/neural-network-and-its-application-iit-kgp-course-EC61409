# %% [markdown]
# ***This program is  for 4 class classification by using DarkCovidNet model***

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# ### Data

# %% [markdown]
# **here** i have imported the drive if you want to import this drive then please mail me at bhosale1prathmesh@gmail.com i will share drive instantaneously

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = Path('/content/drive/MyDrive/upload_by_pratham_xray_4_class')

# %% [markdown]
# here we are giving path,batch size, train folder validation folder

# %%
np.random.seed(41)
data = ImageDataBunch.from_folder(path, train="train", valid ="val",
        ds_tfms=get_transforms(), size=(256,256), bs=32, num_workers=4).normalize()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/transform.py:247: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   return _solve_func(B,A)[0][:,0]
# ...

# %% [markdown]
# data class, train data length ,test data length

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['covid', 'lung_ob', 'normal', 'pneumonia'], 4, 4000, 1600)

# %%
print("Number of examples in training:", len(data.train_ds))
print("Number of examples in validation:", len(data.valid_ds))
# Out:
# Number of examples in training: 4000
# Number of examples in validation: 1600

# %%
xb,yb = data.one_batch()
xb.shape,yb.shape
# Out:
# (torch.Size([32, 3, 256, 256]), torch.Size([32]))

# %%
#Sample images from the dataset
data.show_batch(rows=3, figsize=(10,10))

# %% [markdown]
# ## proposed DarkCovidNet model

# %%
def conv_block(ni, nf, size=3, stride=1):
    for_pad = lambda s: s if s > 2 else 3
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=size, stride=stride,
                  padding=(for_pad(size) - 1)//2, bias=False), 
        nn.BatchNorm2d(nf),
        nn.LeakyReLU(negative_slope=0.1, inplace=True)  
    )

# %%
def triple_conv(ni, nf):
    return nn.Sequential(
        conv_block(ni, nf),
        conv_block(nf, ni, size=1),  
        conv_block(ni, nf)
    )

# %%
def maxpooling():
    return nn.MaxPool2d(2, stride=2)

# %% [markdown]
# **cnn** sequential of model

# %%
model = nn.Sequential(
    conv_block(3, 8),
    maxpooling(),
    conv_block(8, 16),
    maxpooling(),
    triple_conv(16, 32),
    maxpooling(),
    triple_conv(32, 64),
    maxpooling(),
    triple_conv(64, 128),
    maxpooling(),
    triple_conv(128, 256),
    conv_block(256, 128, size=1),
    conv_block(128, 256),
    conv_layer(256, 2),
    Flatten(),
    nn.Linear(338, 4)
)

# %%
learn = Learner(data, model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
print(learn.summary())
# Out:
# Sequential
# ...
# Layer (type)         Output Shape         Param #    Trainable
# ...
# Conv2d               [8, 256, 256]        216        True
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 256]        16         True
# ______________________________________________________________________
# LeakyReLU            [8, 256, 256]        0          False
# ______________________________________________________________________
# MaxPool2d            [8, 128, 128]        0          False
# ______________________________________________________________________
# Conv2d               [16, 128, 128]       1,152      True
# ______________________________________________________________________
# BatchNorm2d          [16, 128, 128]       32         True
# ______________________________________________________________________
# LeakyReLU            [16, 128, 128]       0          False
# ...

# %%
learn.fit_one_cycle(20, max_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.037049</td>
#       <td>0.246190</td>
#       <td>0.936875</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.032079</td>
#       <td>0.222401</td>
#       <td>0.943750</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.061191</td>
#       <td>0.378455</td>
#       <td>0.911250</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078581</td>
#       <td>0.249471</td>
#       <td>0.923750</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.108076</td>
#       <td>0.259116</td>
#       <td>0.920000</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **plots of accuracy and losses vs batches processed**

# %%
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
print("Number of examples in testing:", len(data.valid_ds))
# Out:
# Number of examples in testing: 1600

# %%
probs,targets = learn.get_preds(ds_type=DatasetType.Valid)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# **accuracy**

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['covid', 'lung_ob', 'normal', 'pneumonia'], 4, 4000, 1600)

# %% [markdown]
# **precision ,  recall , f1-score**

# %%
print(len(probs))
probs = np.argmax(probs, axis=1)

correct = 0 
for idx, pred in enumerate(probs):
    if pred == targets[idx]:
        correct += 1
accuracy = correct / len(probs)
print(len(probs), correct, accuracy)

from sklearn.metrics import confusion_matrix
np.set_printoptions(threshold=np.inf) 
cm1 = confusion_matrix(targets, probs)
print(cm1)

from sklearn.metrics import classification_report
y_true1 = targets
y_pred1 = probs
target_names = ['Covid-19', 'lung_opacity','No_findings', 'pneumonia']
print(classification_report(y_true1, y_pred1, target_names=target_names))
# Out:
# 1600
# 1600 1504 0.94
# [[367  28   1   4]
#  [  3 391   6   0]
#  [  0   0 393   7]
#  [  0   0  47 353]]
#               precision    recall  f1-score   support
#
#     Covid-19       0.99      0.92      0.95       400
# lung_opacity       0.93      0.98      0.95       400
#  No_findings       0.88      0.98      0.93       400
#    pneumonia       0.97      0.88      0.92       400
#
#     accuracy                           0.94      1600
#    macro avg       0.94      0.94      0.94      1600
# weighted avg       0.94      0.94      0.94      1600

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# **confusion matrix** for 3 class

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
plt.title('4 class confusion matrix covid vs lung_pacity vs no findings vs pneumonia')

group_counts =[ "{0:0.0f}".format(value) for value in 
                    cm1.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cm1.flatten()/np.sum(cm1)]
categories = ['Covid-19', 'lung_opacity','No_findings', 'pneumonia']

labels = [f"{v2}\n{v3}" for v2, v3 in
          zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(4,4)
sns.heatmap(cm1, annot=labels, fmt='', cmap='Blues',xticklabels=categories,yticklabels=categories)
